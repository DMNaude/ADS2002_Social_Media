# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import string
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
import ast

import warnings
warnings.filterwarnings('ignore')


#Read cleaned and wrangled data
twitter = pd.read_csv("twitter_cleaned.csv", index_col = 0)
instagram = pd.read_csv("instagram_cleaned.csv", index_col = 0)
facebook = pd.read_csv("facebook_cleaned.csv", index_col = 0)

#Ensure that tokens are read as lists, not strings
twitter['tokens'] = twitter['tokens'].map(ast.literal_eval)
instagram['tokens'] = instagram['tokens'].map(ast.literal_eval)
facebook['tokens'] = facebook['tokens'].map(ast.literal_eval)

#STOPWORDS & STEMMING
stopwords = nltk.corpus.stopwords.words("english") 
ps = PorterStemmer()

#can change to WordNetLemmatizer().lemmatize(word)
for i, tokenset in twitter.tokens.items():
    twitter.tokens[i] = [ps.stem(word) for word in tokenset if word.lower() not in stopwords]
for j, tokenset in instagram.tokens.items():
    instagram.tokens[j] = [ps.stem(word) for word in tokenset if word.lower() not in stopwords]
for k, tokenset in facebook.tokens.items():
    facebook.tokens[k] = [ps.stem(word) for word in tokenset if word.lower() not in stopwords]

# %%
#BUILDING CORPORA
twitter_corpus = []
instagram_corpus = []
facebook_corpus = []

#ADD ALL TOKENS TO CORPUS
for tokenset in twitter.tokens:
    twitter_corpus += tokenset
for tokenset in instagram.tokens:
    instagram_corpus += tokenset
for tokenset in facebook.tokens:
    facebook_corpus += tokenset
    
#REMOVE STOPWORDS
# twitter_corpus = [word for word in twitter_corpus if word.lower() not in stopwords]
# instagram_corpus = [word for word in instagram_corpus if word.lower() not in stopwords]
# facebook_corpus = [word for word in facebook_corpus if word.lower() not in stopwords]

#BUILD FREQUENCY DISTRIBUTIONS
twitter_fd = nltk.FreqDist(twitter_corpus)
instagram_fd = nltk.FreqDist(instagram_corpus)
facebook_fd = nltk.FreqDist(facebook_corpus)

# %%
twitter_fd["argentina".lower()]
# Out:
# 1759

# %%
twitter_fd.plot(30, title = "Twitter Word Frequency");

# %%
instagram_fd.plot(30, title = "Instagram Word Frequency");

# %%
facebook_fd.plot(30, title = "Facebook Word Frequency");

# %%
twitter_text = nltk.Text(twitter_corpus)

# %%
#pip install gensim

# %%
from gensim import corpora, models

#CREATE A DICTIONARY OF TWEETS
dictionary = corpora.Dictionary(twitter.tokens) 
#REMOVE EXTREMES
dictionary.filter_extremes(no_below=15, no_above=0.5, keep_n=100000) 
#CONVERT TO BAG OF WORDS CORPUS
bow_corpus = [dictionary.doc2bow(doc) for doc in twitter.tokens]

#CREATE TF-IDF CORPUS FOR LDA MODELLING
tfidf = models.TfidfModel(bow_corpus)
corpus_tfidf = tfidf[bow_corpus]

# %%
#CREATE LDA MODEL FROM BOW CORPUS
lda_model = models.LdaMulticore(bow_corpus, num_topics=15, id2word=dictionary, passes=2, workers=2, random_state=42)

# %%
#PRINT EACH TOPIC FROM THE LDA MODEL
for idx, topic in lda_model.print_topics(-1):
    print('Topic: {} \nWords: {}'.format(idx, topic))
# Out:
# Topic: 0
# Words: 0.076*"2022" + 0.057*"fifa" + 0.057*"live" + 0.041*"vs" + 0.030*"fifaworldcup" + 0.027*"stream" + 0.022*"argentina" + 0.022*"qatar2022" + 0.016*"link" + 0.014*"final"
# Topic: 1
# Words: 0.023*"first" + 0.018*"game" + 0.016*"fan" + 0.015*"match" + 0.015*"ecuador" + 0.015*"host" + 0.014*"fifa" + 0.013*"2022" + 0.012*"stadium" + 0.012*"footbal"
# Topic: 2
# Words: 0.050*"2022" + 0.023*"fifa" + 0.014*"team" + 0.013*"fan" + 0.013*"footbal" + 0.011*"group" + 0.011*"fifaworldcup" + 0.010*"match" + 0.010*"news" + 0.010*"belgium"
# Topic: 3
# Words: 0.030*"die" + 0.028*"grant" + 0.028*"wahl" + 0.025*"journalist" + 0.021*"soccer" + 0.019*"cover" + 0.018*"fan" + 0.015*"2022" + 0.014*"fifa" + 0.011*"us"
# Topic: 4
# Words: 0.040*"worker" + 0.029*"migrant" + 0.026*"2022" + 0.024*"fifa" + 0.015*"death" + 0.013*"die" + 0.011*"right" + 0.010*"build" + 0.008*"win" + 0.008*"human"
# Topic: 5
# Words: 0.028*"2022" + 0.017*"2" + 0.015*"1" + 0.013*"goal" + 0.011*"fifa" + 0.011*"brazil" + 0.010*"ecuador" + 0.010*"qatar2022" + 0.009*"0" + 0.009*"england"
# Topic: 6
# Words: 0.022*"qatar2022" + 0.018*"fifaworldcup" + 0.015*"final" + 0.015*"play" + 0.014*"team" + 0.013*"player" + 0.012*"group" + 0.010*"footbal" + 0.010*"franc" + 0.010*"time"
# Topic: 7
# Words: 0.022*"2022" + 0.021*"beer" + 0.018*"ban" + 0.015*"fifa" + 0.015*"countri" + 0.014*"stadium" + 0.014*"good" + 0.013*"qatar2022" + 0.013*"footbal" + 0.012*"lgbtq"
# Topic: 8
# Words: 0.022*"team" + 0.018*"2022" + 0.014*"qatar2022" + 0.013*"morocco" + 0.013*"african" + 0.012*"brazil" + 0.012*"fifa" + 0.012*"win" + 0.011*"countri" + 0.011*"go"
# Topic: 9
# Words: 0.058*"2022" + 0.044*"fifa" + 0.012*"fan" + 0.011*"qatar2022" + 0.011*"nft" + 0.011*"footbal" + 0.011*"award" + 0.009*"fifaworldcup" + 0.009*"mistak" + 0.007*"host"
# Topic: 10
# Words: 0.028*"messi" + 0.020*"fifa" + 0.020*"fan" + 0.019*"2022" + 0.013*"final" + 0.013*"fifaworldcup" + 0.012*"argentina" + 0.011*"team" + 0.010*"qatar2022" + 0.009*"time"
# Topic: 11
# Words: 0.049*"2022" + 0.028*"fifa" + 0.025*"stream" + 0.017*"1" + 0.016*"link" + 0.016*"worldcup2022" + 0.014*"vidio" + 0.014*"morgan" + 0.013*"live" + 0.013*"freeman"
# Topic: 12
# Words: 0.023*"best" + 0.014*"ever" + 0.012*"say" + 0.011*"england" + 0.011*"peopl" + 0.011*"2022" + 0.010*"qatar2022" + 0.010*"countri" + 0.009*"fifa" + 0.008*"everyon"
# Topic: 13
# Words: 0.026*"host" + 0.022*"fifa" + 0.013*"footbal" + 0.010*"one" + 0.010*"right" + 0.010*"year" + 0.008*"time" + 0.008*"tournament" + 0.007*"watch" + 0.007*"human"
# Topic: 14
# Words: 0.015*"fifa" + 0.013*"alcohol" + 0.012*"stadium" + 0.010*"2022" + 0.010*"qatar2022" + 0.010*"ban" + 0.010*"fan" + 0.008*"protest" + 0.008*"win" + 0.008*"iran"

# %%
#EXAMPLE TOPIC PROBABILITIES
lda_model.get_document_topics(bow_corpus)[40]
# Out:
# [(0, 0.5961561), (6, 0.17513932), (9, 0.14869118)]

# %%
twitter.tokens[40]
# Out:
# ['etern',
#  'glori',
#  'final',
#  'fifa',
#  'world',
#  'cup',
#  'qatar',
#  '2022',
#  'footballcultur',
#  'classicshirt',
#  'footballshirt',
#  'classicfootballshirt',
#  'adida',
#  'worldcup',
#  'qatar',
#  'qatar2022',
#  'vamosargentina',
#  'argentina',
#  'fifaworldcup']

# %%
import operator

#ASSIGN EACH TWEET ITS MOST LIKELY TOPIC
twitter_topics_list = []
for index, topic_probs in enumerate(lda_model.get_document_topics(bow_corpus)):
    likeliest_topic = max(topic_probs, key=operator.itemgetter(1))
    twitter_topics_list.append(likeliest_topic[0])
twitter['topic'] = twitter_topics_list

# %%
#COUNTS OF EACH TOPIC IN THE DATASET
twitter.topic.value_counts()
# Out:
# 0     2760
# 13    2611
# 6     2384
# 5     1975
# 10    1955
# 8     1942
# 14    1812
# 12    1716
# 2     1703
# 3     1700
# 1     1660
# 4     1583
# 7     1563
# 9     1134
# 11    1010
# Name: topic, dtype: int64

# %%
#SAVE THE MODEL TO DISK
#I don't really know where this goes, but I think it works
#I think it goes somewhere into your Anaconda3 path by default
from gensim.test.utils import datapath
fname = datapath("LDA_Twitter_15")
lda_model.save(fname)

# %%
for index, score in sorted(lda_model[bow_corpus[40]], key=lambda tup: -1*tup[1]):
    print("\nScore: {}\t \nTopic: {}".format(score, lda_model.print_topic(index, 10)))
# Out:
# Score: 0.5958835482597351
# Topic: 0.076*"2022" + 0.057*"fifa" + 0.057*"live" + 0.041*"vs" + 0.030*"fifaworldcup" + 0.027*"stream" + 0.022*"argentina" + 0.022*"qatar2022" + 0.016*"link" + 0.014*"final"
#
# Score: 0.1749585121870041
# Topic: 0.022*"qatar2022" + 0.018*"fifaworldcup" + 0.015*"final" + 0.015*"play" + 0.014*"team" + 0.013*"player" + 0.012*"group" + 0.010*"footbal" + 0.010*"franc" + 0.010*"time"
#
# Score: 0.14914456009864807
# Topic: 0.058*"2022" + 0.044*"fifa" + 0.012*"fan" + 0.011*"qatar2022" + 0.011*"nft" + 0.011*"footbal" + 0.011*"award" + 0.009*"fifaworldcup" + 0.009*"mistak" + 0.007*"host"

# %%
#EXAMPLE SENTIMENT ANALYSIS
from nltk.sentiment import SentimentIntensityAnalyzer

sia = SentimentIntensityAnalyzer()

tweet = twitter.iloc[121]
print(tweet.content)
sia.polarity_scores(tweet.content)['compound']
# Out:
# The overriding theme of this World Cup will be Fuck Qatar and Fuck FIFA for me  Forever  Fucking scumbaggery manifest
# -0.7906

# %%
#ASSIGNING EACH TWEET A SENTIMENT SCORE
#This takes a long time
tweet_scores = []
for index, tweet in twitter.iterrows():
    sia = SentimentIntensityAnalyzer()
    tweet_scores.append(sia.polarity_scores(tweet.content)['compound'])
twitter['sentiment'] = tweet_scores
twitter
# Out:
#                                                  content  \
# 0      Kalvin Phillips hopeful of World Cup inclusion...
# 1      Qatar promises a  carbon neutral  FIFA World C...
# 2      Qatar s promise of  carbon neutral  World Cup ...
# 3      Around 6 000 Argentine Fans Banned from Stadiu...
# 4      Happy World Cup Final Day   Argentina to win 2...
# ...                                                  ...
# 27503  FIFA World Cup 2022  Sometimes things don t go...
# 27504     FIFA World Cup Qatar 2022 Match schedule   ...
# 27505  Please am I only one that has not yet watched ...
# 27506  This is what the  FIFAWorldCup is all about   ...
# 27507  Only if i knew that tuning into serbia vs came...
#
#                          from      locatiion              date  \
# 0                  myKhel com      Bengaluru   8/11/2022 10:40
# 1                    Republic  Mumbai  India   8/11/2022 10:58
# 2      Carbon Credit Research      Worldwide   8/11/2022 11:08
# 3                Viral Cyprus      Worldwide   8/11/2022 12:00
# 4                     MrX NFT            NaN  18/12/2022 16:21
# ...                       ...            ...               ...
# 27503      Daily News hunt 24         Mumbai  28/11/2022 21:24
# 27504             K8 Official            NaN   29/11/2022 3:13
# 27505              Anas zurmi       Nigeria    29/11/2022 3:13
# 27506    FIFA World Cup Stats       Global    28/11/2022 21:47
# 27507               TradeStar  Mumbai  India  28/11/2022 21:47
#
#                            by  likes  shares  \
# 0                  myKhel com      0       0
# 1                    Republic     10       1
# 2      Carbon Credit Research      0       0
# 3                Viral Cyprus      0       0
# 4                     MrX NFT      0       0
# ...                       ...    ...     ...
# 27503      Daily News hunt 24      0       0
# 27504             K8 Official      5       1
# 27505              Anas zurmi      5       0
# 27506    FIFA World Cup Stats    124      28
# 27507               TradeStar      0       0
#
#                                                   tokens  topic  sentiment
# 0      [kalvin, phillip, hope, world, cup, inclus, en...      8     0.5106
# 1      [qatar, promis, carbon, neutral, fifa, world, ...     11    -0.2702
# 2      [qatar, promis, carbon, neutral, world, cup, r...      3     0.0258
# 3      [around, 6, 000, argentin, fan, ban, stadium, ...     14    -0.4588
# 4      [happi, world, cup, final, day, argentina, win...      5     0.8176
# ...                                                  ...    ...        ...
# 27503  [fifa, world, cup, 2022, sometim, thing, go, w...      8     0.0772
# 27504  [fifa, world, cup, qatar, 2022, match, schedul...      0     0.5859
# 27505  [pleas, one, yet, watch, even, singl, match, q...     13    -0.4019
# 27506  [fifaworldcup, play, street, footbal, biggest,...      5     0.2023
# 27507  [knew, tune, serbia, vs, cameroon, match, acci...      5     0.3750
#
# [27508 rows x 10 columns]

# %%
topic_sent = twitter.groupby(['topic']).mean().sentiment
topic_colour = [{t in [4,5,7,9,10,11,12,13,14]: "green", t in [0,1,2,3,6,8]: "red"}[True] for t in topic_sent.index]

ax = topic_sent.sort_values().plot.bar(x='lab', y='val', rot=0, color = topic_colour)
plt.title('Average Sentiment by Topic | Twitter')
plt.ylabel('Compound Sentiment Score')
plt.show()

# %%
topic_occ = twitter.groupby(['topic']).count().content
topic_colour = [{t in [0,4,6,7,9,10,11,12,14]: "green", t in [1,2,3,5,8,13]: "red"}[True] for t in topic_sent.index]

ax = topic_occ.sort_values().plot.bar(x='lab', y='val', rot=0, color = topic_colour)
plt.title('Number of Tweets by Topic | Twitter')
plt.ylabel('Tweets')
plt.show()

# %%
twitter = twitter.rename(columns = {'date':'datetime'})
twitter['date'] = pd.to_datetime(twitter['datetime']).dt.date
twitter

# %%
date_sent = twitter[twitter.topic == 4].groupby(['date']).mean().sentiment
date_sent.sort_values().plot()
plt.title('Average Sentiment by Date | Twitter')
plt.ylabel('Compound Sentiment Score')
plt.show()

# %%
date_sent = twitter.groupby(['date']).mean().sentiment
date_sent.sort_values().plot()
plt.title('Average Sentiment by Date | Twitter')
plt.ylabel('Compound Sentiment Score')
plt.show()

# %%
twitter.to_csv("twitter_final.csv")

# %%
lda2 = models.LdaMulticore.load(fname)
